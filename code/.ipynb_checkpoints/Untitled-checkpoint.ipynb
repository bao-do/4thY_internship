# %%
import torch
import torchvision
from torchvision import datasets, transforms
import matplotlib.pyplot as plt
# Out:
# mkdir -p failed for path /home/qbaodo/.cache/matplotlib: [Errno 13] Permission denied: '/home/qbaodo/.cache/matplotlib'
# Matplotlib created a temporary cache directory at /tmp/matplotlib-nfiiski2 because there was an issue with the default path (/home/qbaodo/.cache/matplotlib); it is highly recommended to set the MPLCONFIGDIR environment variable to a writable directory, in particular to speed up the import of Matplotlib and to better support multiprocessing.

# %%
transform = transforms.Compose([
    transforms.ToTensor(),
])

# %%
train_dataset = datasets.MNIST(root='./data',train=True,download=True,transform=transform)
test_dataset = datasets.MNIST(root='./data',train=False,download=True,transform=transform)

# %%
transform = transforms.Compose([
    transforms.ToTensor(),
    # AddGaussianNoise(std=1.)
])

train_dataset = datasets.MNIST(root='./data', train=True,download=False,transform = transform)

# %%
import random
from torch.utils.data import Subset

random.seed(32)
subset_indices = random.sample(range(len(train_dataset)),100)

# %%
dataset = Subset(train_dataset, indices= subset_indices)
loader = DataLoader(dataset,batch_size = 100, shuffle=True)

# %%
sigma = 1.

# %%
import torch.nn as nn
import torch.nn.functional as F

class fftConv2d(nn.Module):
    def __init__(self,in_channels,out_channels,input_size):
        super().__init__()
        self.input_size = input_size
        self.kernel = nn.Parameter(torch.nn.init.xavier_uniform_(torch.empty(out_channels,in_channels,*input_size)))
        
    def forward(self,x):
        B, C_in,H,W = x.shape
        assert (H,W) == self.input_size, "Input size must match the initialized input_size"
        
        x_f = torch.fft.rfft2(x)
        k_f = torch.fft.rfft2(self.kernel)
        
        #out_f = torch.einsum('bcij, ocij -> boij',x_f,k_f)  # b c h w 
        out_f = torch.sum(x_f[:,None] * k_f[None,...], dim = 2) 
        out = torch.fft.irfft2(out_f,s=(H,W))
        
        return out

# %%
class FFTModel(nn.Module):
    def __init__(self,input_size,c_out_list):
        super().__init__()
        self.layers = nn.ModuleList()
        self.input_size = input_size
        self.layers.append(fftConv2d(in_channels=1,out_channels = c_out_list[0],input_size=input_size))
        self.layers.append(nn.ReLU())
        for i in range(len(c_out_list)-1):
            self.layers.append(fftConv2d(in_channels = c_out_list[i],
                                         out_channels = c_out_list[i+1],
                                         input_size = input_size))
            self.layers.append(nn.BatchNorm2d(num_features = c_out_list[i+1]))
            self.layers.append(nn.ReLU())
        
        self.layers.append(fftConv2d(in_channels = c_out_list[-1],
                                         out_channels =1,
                                         input_size = input_size))
        self.output_activation = nn.ReLU()
        
    
    def forward(self,x):
        # input_tensor = x.clone()
        for layer in self.layers:
            x = layer(x)
        x = self.output_activation(x)
        return  x

# %%
from torch.optim.lr_scheduler import LinearLR


device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model =  FFTModel(input_size = (28,28),c_out_list=[2,8,16,8,2]).to(device)

optimizer = torch.optim.Adam(model.parameters(),lr=0.0001)
scheduler = LinearLR(optimizer,0.6,1.,50)
loss_fn = torch.nn.MSELoss(reduction='mean')

print(sum(p.numel() for p in model.parameters() if p.requires_grad))
# Out:
# 228928

# %%
def show_images(tensor):
    tensor = tensor.detach().cpu().permute(0,2,3,1)
    num_images = tensor.size(0)
    cols = num_images
    rows = 1
    
    plt.figure(figsize=(2 * num_images, 2))
    for i, img in enumerate(tensor):
        plt.subplot(rows, cols, i + 1)
        plt.imshow(img)  # Remove `cmap='gray'` for RGB images
        plt.axis('off')  # Hide axes
    plt.tight_layout()
    plt.show()

# %%
from tqdm import tqdm

def train(model,dataloader,optimizer,loss_fn,epochs = 101):
    print("Training starts")
    model.to(device)

    pb_bar = tqdm(range(epochs))
    for epoch in pb_bar:
        model.train()
        running_loss = 0.0
        for X, _ in dataloader:
            X = X.to(device) 
            Y = X + sigma * torch.randn_like(X)

            optimizer.zero_grad()
            outputs = model(Y)
            loss = loss_fn(outputs, X)
            loss.backward()
            optimizer.step()
            running_loss += loss.item()
        avg_loss = running_loss/len(dataloader)
        last_lr = scheduler.get_last_lr()[0]
        pb_bar.set_description(f'Avg loss = {avg_loss:.3e}, lr = {last_lr:.3f}')
        
        scheduler.step()
        with torch.no_grad():
            if epoch%100==0:
                # print(f"Epoch {epoch} Loss : {avg_loss:.6f}, lr: {optimizer.param_groups[0]["lr"]:.6f}")
                show_images(X[:4])
                show_images(Y[:4])
                show_images(outputs[:4])

def predict(model,input_tensor):
    device = next(model.parameters()).device
    model.eval()

    with torch.no_grad():
        input_tensor = input_tensor.to(device)
        output = model(input_tensor)
    return output.cpu()

# %%
train(model, loader, optimizer, loss_fn, epochs=1000)
# Out:
# Training starts
# ...
# Avg loss = 3.170e-02, lr = 0.000: 100%|█████| 1000/1000 [00:34<00:00, 29.22it/s]

# %%
train_pred = predict(model,X)
fig,axs = plt.subplots(3,5,figsize=(15,3))
axs = axs.flat
for i in range(5):
    axs[i].imshow(train_pred[i].squeeze())
for i in range(5,10):
    axs[i].imshow(y[i-5].squeeze())    
for i in range(10,15):
    axs[i].imshow(X[i-10].squeeze())   
plt.show()

# %%
def weights_calculation(x_input,dataset):
    n,h,w = dataset.shape
    dataset_flat = dataset.reshape(-1,h*w)
    x_input_flat = x_input.flatten()
    power = -0.5*torch.linalg.norm(dataset_flat - x_input_flat,dim=1)**2/sigma**2
    # print(power.shape)
    weights_vec = torch.softmax(power,dim=0)
    return weights_vec

# %%
# transH, transV = torch.meshgrid(torch.arange(28),torch.arange(28))
# transH_flat = transH.flatten()
# transV_flat = transV.flatten()

translated_dataset= []
for shift_h in range(28):
    for shift_v in range(28):
        translated_dataset.append(torch.roll(y,shifts=(shift_h,shift_v),dims=(2,3)))

translated_dataset = torch.stack(translated_dataset).reshape(-1,1,28,28).squeeze(1)


print(translated_dataset.shape)
        

fig,axs = plt.subplots(1,5,figsize=(15,3))
axs = axs.flat
for i in range(5):
    axs[i].imshow(translated_dataset[i*100].squeeze())

# %%
# Equivariance verification
translated_im = translated_dataset[1440]
noised_translated_im = translated_im + torch.randn(28,28)*sigma
# plt.imshow(translated_im.squeeze())  
# plt.show()
predicted_im = predict(model,noised_translated_im.unsqueeze(0).unsqueeze(0))
fig,axs = plt.subplots(1,2,figsize=(6,3))
axs=axs.flat
axs[0].imshow(translated_im.squeeze())
axs[0].axis('off')
axs[1].imshow(predicted_im.squeeze())
axs[1].axis('off')
plt.tight_layout()
plt.show()

# %%
idx = 0
x_new_noiseless = y[idx:idx + 1]
x_new = x_new_noiseless + sigma * torch.randn_like(x_new_noiseless)


im_generated = predict(model,x_new)
show_images(torch.cat([x_new, im_generated, x_new_noiseless], dim = 0))

# %%
weights = weights_calculation(x_input=x_new,dataset=translated_dataset)
_, top_indices = torch.topk(weights, k=750)

# %%
fig,axs = plt.subplots(15,50,figsize=(50,15))
axs = axs.flat
for i in range(750):
    axs[i].imshow(translated_dataset[top_indices[i]].squeeze())
    axs[i].axis('off')
plt.tight_layout()
plt.show()

# %%
weights = weights.reshape(-1,1,1)
print(weights.shape)

# %%
image_predicted_analytic = torch.mean(translated_dataset*weights,dim=0)

# %%
plt.imshow(image_predicted_analytic)
plt.show()

# %%
translated_dataset.shape

# %%
from torcheval.metrics import R2Score
mse_theorical_cnn = torch.mean(torch.linalg.norm(image_predicted_analytic-im_generated))
# metric_r2 = R2Score()
# metric_r2.update(im_generated.flatten(),image_predicted_analytic.flatten())
# r2=metric_r2.compute()
print(f"mse: {mse_theorical_cnn}")

# %%
plt.imshow(y[90].squeeze())
